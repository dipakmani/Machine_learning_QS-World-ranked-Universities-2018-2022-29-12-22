# %%
About Dataset
Context
This Dataset is about top universities around the world according QS ranking from 2018 to 2022, Life Science and Medicine 
Department. This is a Clear Dataset.

Contains
This dataset is containing 6 columns and 5200+ rows.
Year : This column has value 2018,2019,2020,2021,2022
Rank : Rank is given by QS according to point starts with 1
Name : Every University names based on Rank
Point : Every University has own earned point, based on education quality, faculty facilities, student facilities and so on
City : A university located city.
Country : University's located Country

Target
Using this dataset you can do awesome analysis and build a story.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("QS World ranked Universities (2018-2022).csv")

# %%
df
# Out:
#       Year  Rank                                         Name  Point  \
# 0     2018     1                           Harvard University   97.7
# 1     2018     2                      University of Cambridge   94.6
# 2     2018     2                         University of Oxford   94.6
# 3     2018     4  Massachusetts Institute of Technology (MIT)   92.5
# 4     2018     5                     Johns Hopkins University   92.1
# ...    ...   ...                                          ...    ...
# 5245  2022   346        National Cheng Kung University (NCKU)   60.7
# 5246  2022   346                     University of New Mexico   60.7
# 5247  2022   348                        Universitas Indonesia   60.6
# 5248  2022   349                          Aga Khan University   60.5
# 5249  2022   349                      Northeastern University   60.5
#
#              City          Country
# 0       Cambridge    United States
# 1       Cambridge   United Kingdom
# 2          Oxford   United Kingdom
# 3       Cambridge    United States
# 4       Baltimore    United States
# ...           ...              ...
# 5245  Tainan City           Taiwan
# 5246  Albuquerque    United States
# 5247        Depok        Indonesia
# 5248      Karachi         Pakistan
# 5249       Boston    United States
#
# [5250 rows x 6 columns]

# %%
df.head()
# Out:
#    Year  Rank                                         Name  Point       City  \
# 0  2018     1                           Harvard University   97.7  Cambridge
# 1  2018     2                      University of Cambridge   94.6  Cambridge
# 2  2018     2                         University of Oxford   94.6     Oxford
# 3  2018     4  Massachusetts Institute of Technology (MIT)   92.5  Cambridge
# 4  2018     5                     Johns Hopkins University   92.1  Baltimore
#
#            Country
# 0    United States
# 1   United Kingdom
# 2   United Kingdom
# 3    United States
# 4    United States

# %%
df.tail()
# Out:
#       Year  Rank                                   Name  Point         City  \
# 5245  2022   346  National Cheng Kung University (NCKU)   60.7  Tainan City
# 5246  2022   346               University of New Mexico   60.7  Albuquerque
# 5247  2022   348                  Universitas Indonesia   60.6        Depok
# 5248  2022   349                    Aga Khan University   60.5      Karachi
# 5249  2022   349                Northeastern University   60.5       Boston
#
#              Country
# 5245          Taiwan
# 5246   United States
# 5247       Indonesia
# 5248        Pakistan
# 5249   United States

# %%
df.shape
# Out:
# (5250, 6)

# %%
df['Country'].unique()
# Out:
# array([' United States', ' United Kingdom', ' Sweden', ' Canada',
#        ' Australia', ' Japan', ' Singapore', ' Denmark', ' Netherlands',
#        ' South Korea', ' Germany', 'Hong Kong', ' Switzerland',
#        ' Belgium', 'China', ' Finland', ' Taiwan', ' Spain',
#        ' New Zealand', ' Italy', ' Norway', ' Ireland', ' South Africa',
#        ' Brazil', ' France', ' Austria', ' Thailand', ' Mexico',
#        ' Israel', ' Argentina', ' Chile', ' Czech Republic', ' Portugal',
#        ' Malaysia', ' Egypt', ' Greece', ' Hungary', ' Saudi Arabia',
#        ' Turkey', ' Russia', ' India', ' Pakistan', ' Lebanon',
#        ' Estonia', ' Czechia', ' Poland', ' Iran', ' Indonesia'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     5250 non-null   int64
#  1   Rank     5250 non-null   int64
#  2   Name     5250 non-null   object
#  3   Point    5030 non-null   float64
#  4   City     5250 non-null   object
#  5   Country  5249 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 246.2+ KB

# %%
df.describe()
# Out:
#               Year         Rank        Point
# count  5250.000000  5250.000000  5030.000000
# mean   2020.666667   174.803429    70.840040
# std       1.247338   100.807265     8.128413
# min    2018.000000     1.000000    57.500000
# 25%    2020.000000    88.000000    64.500000
# 50%    2021.000000   175.000000    69.100000
# 75%    2022.000000   262.000000    76.000000
# max    2022.000000   350.000000    99.000000

# %%
df.describe().T
# Out:
#         count         mean         std     min     25%     50%     75%     max
# Year   5250.0  2020.666667    1.247338  2018.0  2020.0  2021.0  2022.0  2022.0
# Rank   5250.0   174.803429  100.807265     1.0    88.0   175.0   262.0   350.0
# Point  5030.0    70.840040    8.128413    57.5    64.5    69.1    76.0    99.0

# %%
df.columns
# Out:
# Index(['Year', 'Rank', 'Name', 'Point', 'City', 'Country'], dtype='object')

# %%
df.isnull()
# Out:
#        Year   Rank   Name  Point   City  Country
# 0     False  False  False  False  False    False
# 1     False  False  False  False  False    False
# 2     False  False  False  False  False    False
# 3     False  False  False  False  False    False
# 4     False  False  False  False  False    False
# ...     ...    ...    ...    ...    ...      ...
# 5245  False  False  False  False  False    False
# 5246  False  False  False  False  False    False
# 5247  False  False  False  False  False    False
# 5248  False  False  False  False  False    False
# 5249  False  False  False  False  False    False
#
# [5250 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Year         0
# Rank         0
# Name         0
# Point      220
# City         0
# Country      1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 221

# %%
df.shape
# Out:
# (5250, 6)

# %%
df.notnull()
# Out:
#       Year  Rank  Name  Point  City  Country
# 0     True  True  True   True  True     True
# 1     True  True  True   True  True     True
# 2     True  True  True   True  True     True
# 3     True  True  True   True  True     True
# 4     True  True  True   True  True     True
# ...    ...   ...   ...    ...   ...      ...
# 5245  True  True  True   True  True     True
# 5246  True  True  True   True  True     True
# 5247  True  True  True   True  True     True
# 5248  True  True  True   True  True     True
# 5249  True  True  True   True  True     True
#
# [5250 rows x 6 columns]

# %%
df.notnull().sum()
# Out:
# Year       5250
# Rank       5250
# Name       5250
# Point      5030
# City       5250
# Country    5249
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 31279

# %%
df.shape
# Out:
# (5250, 6)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Year       0
# Rank       0
# Name       0
# Point      0
# City       0
# Country    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Rank', 'Name', 'Point', 'City', 'Country'], dtype='object')

# %%
df['City'].value_counts()
# Out:
# -                97
# London           87
# New York City    83
# Seoul            60
# Tokyo            50
#                  ..
# Taipei            1
# Hsinchu City      1
# Belfast           1
# Hong Kong SAR     1
# Depok             1
# Name: City, Length: 312, dtype: int64

# %%
df.shape
# Out:
# (5029, 6)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Year         int64
# Rank         int64
# Name        object
# Point      float64
# City        object
# Country     object
# dtype: object

# %% [markdown]
# ## EDA

# %%
## viewing null value using heatmap
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
##Viewing Country data using countplot
sns.set_style('whitegrid')
sns.countplot(x='Country',data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
# Distribution of Universities by country

plt.figure(figsize=(15,8))
sns.countplot(data=df, x='Country')
plt.title('Number of Universities in QS University Rankings by Country')
plt.xticks(rotation=90)
plt.show()

# %%
# Segregate the ranking year wise
df2018 = df[df['Year']==2018]
df2019 = df[df['Year']==2019]
df2020 = df[df['Year']==2020]
df2021 = df[df['Year']==2021]
df2022 = df[df['Year']==2022]

# %%
#print the top 5 Universities 
df2022.head()
# Out:
#       Year  Rank                                         Name  Point  \
# 3500  2022     1                           Harvard University   97.7
# 3501  2022     2                      University of Cambridge   94.6
# 3502  2022     2                         University of Oxford   94.6
# 3503  2022     4  Massachusetts Institute of Technology (MIT)   92.5
# 3504  2022     5                     Johns Hopkins University   92.1
#
#            City          Country
# 3500  Cambridge    United States
# 3501  Cambridge   United Kingdom
# 3502     Oxford   United Kingdom
# 3503  Cambridge    United States
# 3504  Baltimore    United States

# %%
# last 5 raked universities
df2022.tail()
# Out:
#       Year  Rank                                   Name  Point         City  \
# 5245  2022   346  National Cheng Kung University (NCKU)   60.7  Tainan City
# 5246  2022   346               University of New Mexico   60.7  Albuquerque
# 5247  2022   348                  Universitas Indonesia   60.6        Depok
# 5248  2022   349                    Aga Khan University   60.5      Karachi
# 5249  2022   349                Northeastern University   60.5       Boston
#
#              Country
# 5245          Taiwan
# 5246   United States
# 5247       Indonesia
# 5248        Pakistan
# 5249   United States

# %%
#plot the points scored by Universities from different countries
plt.figure(figsize=(15,7))
sns.boxplot(data=df,x='Country',y='Point')
plt.xticks(rotation=90)
plt.title('University points scored by countries')
plt.show()

# %%
dfs = [df2018,df2019,df2020,df2021,df2022]
year=2018
for df in dfs:
    plt.figure(figsize=(15,7))
    df['Country'].value_counts().plot.bar(color='red')
    text=str(year)
    plt.title('Number of Universities in QS World University Rankings by Country for the year '+text)
    year=year+1
    plt.show()

# %%
#create individual data frames of value count of number of universities per year
dfs=[df2018,df2019,df2020,df2021,df2022]
year=2018
counts=[]
for df in dfs:
    
    counts.append(pd.DataFrame(df['Country'].value_counts()))

# %%
#Add years as the column headings
year=2018
for i in counts:
    col=str(year)
    i.columns=[col]
    year=year+1
counts
# Out:
# [                 2018
#   United States     96
#   Germany           28
#   United Kingdom    26
#   Australia         17
#   Japan             13
#   Italy             12
#   Canada            12
#  China              11
#   Netherlands       10
#   France            10
#   Sweden             8
#   South Korea        8
#   Switzerland        7
#   Belgium            7
#   Brazil             7
#   Spain              7
#   Taiwan             6
#   Denmark            4
#   Ireland            4
#   South Africa       4
#   Israel             4
#   Finland            4
#   Norway             3
#  Hong Kong           3
#   Austria            3
#   Portugal           2
#   Greece             2
#   Malaysia           2
#   Chile              2
#   Czech Republic     2
#   Singapore          2
#   Thailand           2
#   Argentina          1
#   Mexico             1
#   Egypt              1
#   New Zealand        1
#   Hungary            1
#   Saudi Arabia       1
#   Turkey             1,
#                   2019
#   United States    196
#   Germany           57
#   United Kingdom    51
#   Australia         32
#   Canada            25
#   Italy             25
#   Japan             24
#  China              23
#   France            21
#   Netherlands       19
#   Sweden            16
#   South Korea       16
#   Switzerland       14
#   Belgium           14
#   Spain             14
#   Brazil            13
#   Taiwan            12
#   Ireland            8
#   Finland            8
#   Denmark            8
#   Israel             8
#   South Africa       7
#   Austria            6
#   Norway             6
#  Hong Kong           5
#   Portugal           4
#   Greece             4
#   Thailand           4
#   Singapore          4
#   Chile              4
#   Malaysia           4
#   Turkey             3
#   Czech Republic     3
#   Saudi Arabia       2
#   Hungary            2
#   New Zealand        2
#   Egypt              2
#   Argentina          2
#   Mexico             2
#   Russia             1
#   India              1,
#                   2020
#   United States    291
#   Germany           84
#   United Kingdom    76
#   Australia         49
#   Canada            38
#   Italy             38
#  China              36
#   Japan             34
#   France            32
#   Netherlands       28
#   Sweden            24
#   South Korea       24
#   Spain             22
#   Switzerland       21
#   Belgium           21
#   Brazil            20
#   Taiwan            17
#   Finland           13
#   Israel            12
#   Ireland           12
#   Denmark           12
#   South Africa      11
#   Austria           10
#   Norway             9
#  Hong Kong           7
#   Portugal           6
#   Thailand           6
#   Singapore          6
#   Greece             6
#   Chile              6
#   Turkey             5
#   Malaysia           5
#   Czech Republic     4
#   New Zealand        3
#   Egypt              3
#   Argentina          3
#   Hungary            3
#   Saudi Arabia       3
#   Mexico             3
#   Russia             2
#   India              2
#   Pakistan           1
#   Lebanon            1,
#                   2021
#   United States    388
#   Germany          110
#   United Kingdom   101
#   Australia         64
#   Canada            52
#   Italy             50
#  China              50
#   Japan             44
#   France            41
#   Netherlands       37
#   Sweden            32
#   South Korea       32
#   Spain             30
#   Switzerland       28
#   Belgium           28
#   Brazil            27
#   Taiwan            23
#   Finland           18
#   Denmark           17
#   Ireland           16
#   Israel            16
#   Austria           14
#   South Africa      14
#   Norway            12
#  Hong Kong           9
#   Portugal           8
#   Singapore          8
#   Greece             8
#   Chile              8
#   Thailand           7
#   Turkey             7
#   Malaysia           5
#   Czech Republic     5
#   New Zealand        4
#   Egypt              4
#   Argentina          4
#   Hungary            4
#   Saudi Arabia       4
#   Mexico             4
#   Russia             3
#   India              3
#   Lebanon            2
#   Pakistan           1
#   Estonia            1,
#                   2022
#   United States    479
#   Germany          137
#   United Kingdom   123
#   Australia         79
#   Canada            65
#  China              62
#   Italy             61
#   Japan             54
#   France            52
#   Netherlands       46
#   South Korea       39
#   Sweden            39
#   Spain             38
#   Switzerland       35
#   Belgium           35
#   Brazil            34
#   Taiwan            28
#   Denmark           21
#   Finland           21
#   Ireland           20
#   Israel            20
#   Austria           18
#   South Africa      18
#   Norway            15
#  Hong Kong          11
#   Portugal          11
#   Greece            10
#   Singapore         10
#   Chile             10
#   Turkey             9
#   Thailand           8
#   Malaysia           6
#   India              5
#   Saudi Arabia       5
#   Hungary            5
#   Egypt              5
#   Czech Republic     5
#   Argentina          5
#   Mexico             5
#   New Zealand        5
#   Russia             4
#   Lebanon            3
#   Pakistan           2
#   Estonia            2
#   Czechia            2
#   Poland             1
#   Iran               1
#   Indonesia          1]

# %%
#make a total data frame of all years counts (keeping only countries that were there in 2018 ranking list)
counts[0]['2019']=counts[1]['2019']
counts[0]['2020']=counts[2]['2020']
counts[0]['2021']=counts[3]['2021']
counts[0]['2022']=counts[4]['2022']

fin_count=counts[0]
fin_count
# Out:
#                  2018  2019  2020  2021  2022
#  United States     96   196   291   388   479
#  Germany           28    57    84   110   137
#  United Kingdom    26    51    76   101   123
#  Australia         17    32    49    64    79
#  Japan             13    24    34    44    54
#  Italy             12    25    38    50    61
#  Canada            12    25    38    52    65
# China              11    23    36    50    62
#  Netherlands       10    19    28    37    46
#  France            10    21    32    41    52
#  Sweden             8    16    24    32    39
#  South Korea        8    16    24    32    39
#  Switzerland        7    14    21    28    35
#  Belgium            7    14    21    28    35
#  Brazil             7    13    20    27    34
#  Spain              7    14    22    30    38
#  Taiwan             6    12    17    23    28
#  Denmark            4     8    12    17    21
#  Ireland            4     8    12    16    20
#  South Africa       4     7    11    14    18
#  Israel             4     8    12    16    20
#  Finland            4     8    13    18    21
#  Norway             3     6     9    12    15
# Hong Kong           3     5     7     9    11
#  Austria            3     6    10    14    18
#  Portugal           2     4     6     8    11
#  Greece             2     4     6     8    10
#  Malaysia           2     4     5     5     6
#  Chile              2     4     6     8    10
#  Czech Republic     2     3     4     5     5
#  Singapore          2     4     6     8    10
#  Thailand           2     4     6     7     8
#  Argentina          1     2     3     4     5
#  Mexico             1     2     3     4     5
#  Egypt              1     2     3     4     5
#  New Zealand        1     2     3     4     5
#  Hungary            1     2     3     4     5
#  Saudi Arabia       1     2     3     4     5
#  Turkey             1     3     5     7     9

# %%
#plot showing the growth of number of Universities in the QS rankings
plt.figure(figsize=(25,12))
fin_count.plot(kind='bar',figsize=(20,10))
plt.show()

# %%
#compute percentage change in number of Universities from 2018 to 2022
fin_count['per_ch']=(fin_count['2022']-fin_count['2018'])/fin_count['2018']*100
fin_count
# Out:
#                  2018  2019  2020  2021  2022      per_ch
#  United States     96   196   291   388   479  398.958333
#  Germany           28    57    84   110   137  389.285714
#  United Kingdom    26    51    76   101   123  373.076923
#  Australia         17    32    49    64    79  364.705882
#  Japan             13    24    34    44    54  315.384615
#  Italy             12    25    38    50    61  408.333333
#  Canada            12    25    38    52    65  441.666667
# China              11    23    36    50    62  463.636364
#  Netherlands       10    19    28    37    46  360.000000
#  France            10    21    32    41    52  420.000000
#  Sweden             8    16    24    32    39  387.500000
#  South Korea        8    16    24    32    39  387.500000
#  Switzerland        7    14    21    28    35  400.000000
#  Belgium            7    14    21    28    35  400.000000
#  Brazil             7    13    20    27    34  385.714286
#  Spain              7    14    22    30    38  442.857143
#  Taiwan             6    12    17    23    28  366.666667
#  Denmark            4     8    12    17    21  425.000000
#  Ireland            4     8    12    16    20  400.000000
#  South Africa       4     7    11    14    18  350.000000
#  Israel             4     8    12    16    20  400.000000
#  Finland            4     8    13    18    21  425.000000
#  Norway             3     6     9    12    15  400.000000
# Hong Kong           3     5     7     9    11  266.666667
#  Austria            3     6    10    14    18  500.000000
#  Portugal           2     4     6     8    11  450.000000
#  Greece             2     4     6     8    10  400.000000
#  Malaysia           2     4     5     5     6  200.000000
#  Chile              2     4     6     8    10  400.000000
#  Czech Republic     2     3     4     5     5  150.000000
#  Singapore          2     4     6     8    10  400.000000
#  Thailand           2     4     6     7     8  300.000000
#  Argentina          1     2     3     4     5  400.000000
#  Mexico             1     2     3     4     5  400.000000
#  Egypt              1     2     3     4     5  400.000000
#  New Zealand        1     2     3     4     5  400.000000
#  Hungary            1     2     3     4     5  400.000000
#  Saudi Arabia       1     2     3     4     5  400.000000
#  Turkey             1     3     5     7     9  800.000000

# %%
#plot percentage of increase in number of universities from 2018 to 2022
plt.figure(figsize=(20,12))
sns.barplot(data=fin_count,x=fin_count.index,y='per_ch')
plt.title('Percentage increase in number of Universities in QS word University Rankings from 2018 to 2022')
plt.xticks(rotation=90)
plt.show()
